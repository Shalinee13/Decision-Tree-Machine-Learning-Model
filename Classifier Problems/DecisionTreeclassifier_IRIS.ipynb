# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("IRIS.csv")
data
# Out:
#      sepal-length  sepal-width  petal-length  petal-width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.shape
# Out:
# (150, 5)

# %%
data.dtypes
# Out:
# sepal-length    float64
# sepal-width     float64
# petal-length    float64
# petal-width     float64
# species          object
# dtype: object

# %%
data.columns
# Out:
# Index(['sepal-length', 'sepal-width', 'petal-length', 'petal-width',
#        'species'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# sepal-length    0
# sepal-width     0
# petal-length    0
# petal-width     0
# species         0
# dtype: int64

# %%
sns.catplot(x="species",y="sepal-width",kind="box",data=data)   
plt.title("Box plot grouped by sepal-width")
plt.show()

# %%
sns.catplot(x="species",y="sepal-length",kind="box",data=data)   
plt.title("Box plot grouped by sepal-length")
plt.show()

# %%
sns.catplot(x="species",y="petal-length",kind="box",data=data)   
plt.title("Box plot grouped by petal-length")
plt.show()

# %%
sns.catplot(x="species",y="petal-width",kind="box",data=data)   
plt.title("Box plot grouped by petal-width")
plt.show()

# %%
plt.scatter(data["petal-length"],data["petal-width"])     ##scatter
plt.title("Scatter plot")
plt.xlabel("petal-length")
plt.ylabel("petal-width")
plt.show()

# %%
data['species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
X=data[["sepal-length","sepal-width","petal-length","petal-width"]].values

# %%
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
Y=data['species']

# %%
Y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: species, Length: 150, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %% [markdown]
# ## DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier()

# %%
model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predict = model.predict(X_test)

# %%
y_predict
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
data_new = pd.DataFrame({'Actual':Y_test,'Predicted':y_predict})

# %%
data_new
# Out:
#               Actual        Predicted
# 70   Iris-versicolor   Iris-virginica
# 106   Iris-virginica  Iris-versicolor
# 93   Iris-versicolor  Iris-versicolor
# 71   Iris-versicolor  Iris-versicolor
# 27       Iris-setosa      Iris-setosa
# 102   Iris-virginica   Iris-virginica
# 39       Iris-setosa      Iris-setosa
# 149   Iris-virginica   Iris-virginica
# 2        Iris-setosa      Iris-setosa
# 8        Iris-setosa      Iris-setosa
# 3        Iris-setosa      Iris-setosa
# 20       Iris-setosa      Iris-setosa
# 129   Iris-virginica  Iris-versicolor
# 100   Iris-virginica   Iris-virginica
# 56   Iris-versicolor  Iris-versicolor
# 73   Iris-versicolor  Iris-versicolor
# 105   Iris-virginica   Iris-virginica
# 148   Iris-virginica   Iris-virginica
# 32       Iris-setosa      Iris-setosa
# 10       Iris-setosa      Iris-setosa
# 30       Iris-setosa      Iris-setosa
# 95   Iris-versicolor  Iris-versicolor
# 6        Iris-setosa      Iris-setosa
# 75   Iris-versicolor  Iris-versicolor
# ...

# %% [markdown]
# ## accuracy_score

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy =accuracy_score(Y_test,y_predict)*100

# %%
accuracy
# Out:
# 93.33333333333333

# %%
from sklearn.metrics import confusion_matrix

# %%
performance = confusion_matrix(Y_test,y_predict)

# %%
performance
# Out:
# array([[14,  0,  0],
#        [ 0, 13,  1],
#        [ 0,  2, 15]], dtype=int64)

# %%
from sklearn.metrics import plot_confusion_matrix

# %%
plot_confusion_matrix(model,X_test,Y_test)
plt.show()

# %%
from sklearn.metrics import classification_report

# %%
report =classification_report(Y_test,y_predict)

# %%
print(report)
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        14
# Iris-versicolor       0.87      0.93      0.90        14
#  Iris-virginica       0.94      0.88      0.91        17
#
#        accuracy                           0.93        45
#       macro avg       0.93      0.94      0.94        45
#    weighted avg       0.93      0.93      0.93        45

# %%
#clf = DecisionTreeClassifier(criterion="entropy", max_depth=3)

# %%
data.columns
# Out:
# Index(['sepal-length', 'sepal-width', 'petal-length', 'petal-width',
#        'species'],
#       dtype='object')

# %%
from sklearn import tree

# %%
f= ['sepal-length','sepal-width' ,'petal-length','petal-width']

# %%
c=['Iris-setosa','Iris-versicolor','Iris-virginica']

# %%
fig,ax =plt.subplots(nrows=1, ncols=1, figsize=(4,4),dpi=300, facecolor='g')
tree.plot_tree(model,feature_names=f,class_names=c,filled=True)
fig.savefig('decision.png')
plt.show()
